# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 774

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f901eeafc8a1d5aa365bd9af6ef67a46

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
                          
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | arraial do cabo
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | bend
# Processing Record 5 of Set 1 | east london
# Processing Record 6 of Set 1 | ahipara
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | montlucon
# Processing Record 9 of Set 1 | aquiraz
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | georgetown
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | teguldet
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | ayr
# Processing Record 16 of Set 1 | buckeye
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | nea peramos
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | castro
# Processing Record 21 of Set 1 | karlstad
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | dudinka
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | provideniya
# Processing Record 26 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 1 | batemans bay
# Processing Record 28 of Set 1 | klaksvik
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | nikolskoye
# Processing Record 31 of Set 1 | nome
# Processing Record 32 of Set 1 | norman wells
# Processing Record 33 of Set 1 | kenai
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | uthal
# Processing Record 36 of Set 1 | tiarei
# Processing Record 37 of Set 1 | khatanga
# Processing Record 38 of Set 1 | cidreira
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | bengkulu
# Processing Record 41 of Set 1 | jalu
# Processing Record 42 of Set 1 | guerrero negro
# Processing Record 43 of Set 1 | kapaa
# Processing Record 44 of Set 1 | kerema
# Processing Record 45 of Set 1 | altay
# Processing Record 46 of Set 1 | severo-kurilsk
# Processing Record 47 of Set 1 | sidi ali
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | kavieng
# Processing Record 50 of Set 1 | kamaishi
# Processing Record 1 of Set 2 | brigantine
# Processing Record 2 of Set 2 | great falls
# Processing Record 3 of Set 2 | lyuban
# Processing Record 4 of Set 2 | carnarvon
# Processing Record 5 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 6 of Set 2 | araouane
# Processing Record 7 of Set 2 | iqaluit
# Processing Record 8 of Set 2 | hilo
# Processing Record 9 of Set 2 | saint anthony
# Processing Record 10 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 2 | cherskiy
# Processing Record 12 of Set 2 | los llanos de aridane
# Processing Record 13 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 2 | qaanaaq
# Processing Record 15 of Set 2 | ballina
# Processing Record 16 of Set 2 | mahebourg
# Processing Record 17 of Set 2 | catamarca
# Processing Record 18 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 19 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 20 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | la ronge
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | poum
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | sao filipe
# Processing Record 30 of Set 2 | codrington
# Processing Record 31 of Set 2 | ewa beach
# Processing Record 32 of Set 2 | tiksi
# Processing Record 33 of Set 2 | havoysund
# Processing Record 34 of Set 2 | kununurra
# Processing Record 35 of Set 2 | kaitangata
# Processing Record 36 of Set 2 | mar del plata
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | fortuna
# Processing Record 39 of Set 2 | asau
# Processing Record 40 of Set 2 | kiama
# Processing Record 41 of Set 2 | port elizabeth
# Processing Record 42 of Set 2 | lorengau
# Processing Record 43 of Set 2 | wulanhaote
# City not found. Skipping...
# Processing Record 44 of Set 2 | bambanglipuro
# Processing Record 45 of Set 2 | lasa
# Processing Record 46 of Set 2 | vila
# Processing Record 47 of Set 2 | lazaro cardenas
# Processing Record 48 of Set 2 | novaya igirma
# Processing Record 49 of Set 2 | coihaique
# Processing Record 50 of Set 2 | acapulco
# Processing Record 1 of Set 3 | port lincoln
# Processing Record 2 of Set 3 | thompson
# Processing Record 3 of Set 3 | hermanus
# Processing Record 4 of Set 3 | tasiilaq
# Processing Record 5 of Set 3 | xinxiang
# Processing Record 6 of Set 3 | havelock
# Processing Record 7 of Set 3 | plettenberg bay
# Processing Record 8 of Set 3 | skibbereen
# Processing Record 9 of Set 3 | bonthe
# Processing Record 10 of Set 3 | saint-philippe
# Processing Record 11 of Set 3 | ulladulla
# Processing Record 12 of Set 3 | san patricio
# Processing Record 13 of Set 3 | buala
# Processing Record 14 of Set 3 | wyndham
# Processing Record 15 of Set 3 | rudsar
# Processing Record 16 of Set 3 | torbay
# Processing Record 17 of Set 3 | avera
# Processing Record 18 of Set 3 | kargopol
# Processing Record 19 of Set 3 | atar
# Processing Record 20 of Set 3 | lebu
# Processing Record 21 of Set 3 | banda aceh
# Processing Record 22 of Set 3 | abu samrah
# Processing Record 23 of Set 3 | dikson
# Processing Record 24 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 25 of Set 3 | nanortalik
# Processing Record 26 of Set 3 | victoria
# Processing Record 27 of Set 3 | manokwari
# Processing Record 28 of Set 3 | udachnyy
# Processing Record 29 of Set 3 | anton lizardo
# Processing Record 30 of Set 3 | toungoo
# City not found. Skipping...
# Processing Record 31 of Set 3 | adrar
# Processing Record 32 of Set 3 | la palma
# Processing Record 33 of Set 3 | chokurdakh
# Processing Record 34 of Set 3 | airai
# Processing Record 35 of Set 3 | ede
# Processing Record 36 of Set 3 | coria
# Processing Record 37 of Set 3 | mpika
# Processing Record 38 of Set 3 | sisophon
# Processing Record 39 of Set 3 | gobabis
# Processing Record 40 of Set 3 | sanmenxia
# Processing Record 41 of Set 3 | vanavara
# Processing Record 42 of Set 3 | tahta
# Processing Record 43 of Set 3 | pyay
# Processing Record 44 of Set 3 | san cristobal
# Processing Record 45 of Set 3 | baykit
# Processing Record 46 of Set 3 | kasangulu
# Processing Record 47 of Set 3 | taoudenni
# Processing Record 48 of Set 3 | kasaragod
# Processing Record 49 of Set 3 | meulaboh
# Processing Record 50 of Set 3 | saint george
# Processing Record 1 of Set 4 | kranuan
# Processing Record 2 of Set 4 | rewari
# Processing Record 3 of Set 4 | panjab
# Processing Record 4 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 5 of Set 4 | borlange
# City not found. Skipping...
# Processing Record 6 of Set 4 | lagoa
# Processing Record 7 of Set 4 | seoul
# Processing Record 8 of Set 4 | bredasdorp
# Processing Record 9 of Set 4 | morshansk
# Processing Record 10 of Set 4 | dillon
# Processing Record 11 of Set 4 | kutum
# Processing Record 12 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 4 | chumphon
# Processing Record 14 of Set 4 | dingle
# Processing Record 15 of Set 4 | along
# Processing Record 16 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 4 | baijiantan
# Processing Record 18 of Set 4 | sorland
# Processing Record 19 of Set 4 | saint-louis
# Processing Record 20 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 4 | takoradi
# Processing Record 22 of Set 4 | tilichiki
# Processing Record 23 of Set 4 | sitka
# Processing Record 24 of Set 4 | nuuk
# Processing Record 25 of Set 4 | palmas bellas
# Processing Record 26 of Set 4 | novoagansk
# Processing Record 27 of Set 4 | tuatapere
# Processing Record 28 of Set 4 | souillac
# Processing Record 29 of Set 4 | ribeira grande
# Processing Record 30 of Set 4 | askiz
# Processing Record 31 of Set 4 | paracuru
# Processing Record 32 of Set 4 | sao joao da barra
# Processing Record 33 of Set 4 | ponta do sol
# Processing Record 34 of Set 4 | okhotsk
# Processing Record 35 of Set 4 | cabedelo
# Processing Record 36 of Set 4 | faanui
# Processing Record 37 of Set 4 | borgarnes
# Processing Record 38 of Set 4 | filingue
# Processing Record 39 of Set 4 | arman
# Processing Record 40 of Set 4 | coquimbo
# Processing Record 41 of Set 4 | providencia
# Processing Record 42 of Set 4 | margate
# Processing Record 43 of Set 4 | tubuala
# Processing Record 44 of Set 4 | thio
# Processing Record 45 of Set 4 | mulatupo
# Processing Record 46 of Set 4 | wairoa
# Processing Record 47 of Set 4 | civitavecchia
# Processing Record 48 of Set 4 | kavaratti
# Processing Record 49 of Set 4 | port-gentil
# Processing Record 50 of Set 4 | barra do garcas
# Processing Record 1 of Set 5 | lodja
# Processing Record 2 of Set 5 | chuy
# Processing Record 3 of Set 5 | orcopampa
# Processing Record 4 of Set 5 | el estor
# Processing Record 5 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 5 | longyearbyen
# Processing Record 7 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 5 | lujan
# Processing Record 9 of Set 5 | egvekinot
# Processing Record 10 of Set 5 | kostomuksha
# Processing Record 11 of Set 5 | severo-yeniseyskiy
# Processing Record 12 of Set 5 | jumla
# Processing Record 13 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 5 | puerto ayora
# Processing Record 15 of Set 5 | champerico
# Processing Record 16 of Set 5 | hobyo
# Processing Record 17 of Set 5 | tuktoyaktuk
# Processing Record 18 of Set 5 | mayo
# Processing Record 19 of Set 5 | matagami
# Processing Record 20 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 21 of Set 5 | pisco
# Processing Record 22 of Set 5 | ipixuna
# Processing Record 23 of Set 5 | sinnamary
# Processing Record 24 of Set 5 | maloshuyka
# City not found. Skipping...
# Processing Record 25 of Set 5 | sonoita
# Processing Record 26 of Set 5 | ilhabela
# Processing Record 27 of Set 5 | warrnambool
# Processing Record 28 of Set 5 | esperance
# Processing Record 29 of Set 5 | ranong
# Processing Record 30 of Set 5 | waddan
# Processing Record 31 of Set 5 | dali
# Processing Record 32 of Set 5 | pangnirtung
# Processing Record 33 of Set 5 | palu
# Processing Record 34 of Set 5 | gweru
# Processing Record 35 of Set 5 | antigonish
# Processing Record 36 of Set 5 | bulolo
# Processing Record 37 of Set 5 | comodoro rivadavia
# Processing Record 38 of Set 5 | marfino
# Processing Record 39 of Set 5 | umm lajj
# Processing Record 40 of Set 5 | port blair
# Processing Record 41 of Set 5 | vestmanna
# Processing Record 42 of Set 5 | linxia
# Processing Record 43 of Set 5 | chapada dos guimaraes
# Processing Record 44 of Set 5 | ustye
# Processing Record 45 of Set 5 | grindavik
# Processing Record 46 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 5 | mutoko
# Processing Record 48 of Set 5 | hasaki
# Processing Record 49 of Set 5 | garsten
# Processing Record 50 of Set 5 | chinsali
# Processing Record 1 of Set 6 | najran
# Processing Record 2 of Set 6 | sortland
# Processing Record 3 of Set 6 | bethel
# Processing Record 4 of Set 6 | bolobo
# Processing Record 5 of Set 6 | mlimba
# Processing Record 6 of Set 6 | pontes e lacerda
# Processing Record 7 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 6 | pevek
# Processing Record 9 of Set 6 | inhambane
# Processing Record 10 of Set 6 | hebron
# Processing Record 11 of Set 6 | svetlaya
# Processing Record 12 of Set 6 | elko
# Processing Record 13 of Set 6 | tanjong sepat
# City not found. Skipping...
# Processing Record 14 of Set 6 | hailey
# Processing Record 15 of Set 6 | chuguyevka
# Processing Record 16 of Set 6 | naze
# Processing Record 17 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 18 of Set 6 | darnah
# Processing Record 19 of Set 6 | veraval
# Processing Record 20 of Set 6 | hervey bay
# Processing Record 21 of Set 6 | yarada
# Processing Record 22 of Set 6 | te anau
# Processing Record 23 of Set 6 | chupa
# Processing Record 24 of Set 6 | ilulissat
# Processing Record 25 of Set 6 | dunedin
# Processing Record 26 of Set 6 | mehamn
# Processing Record 27 of Set 6 | hambantota
# Processing Record 28 of Set 6 | olafsvik
# Processing Record 29 of Set 6 | port macquarie
# Processing Record 30 of Set 6 | ouesso
# Processing Record 31 of Set 6 | zachagansk
# City not found. Skipping...
# Processing Record 32 of Set 6 | shima
# Processing Record 33 of Set 6 | chiredzi
# Processing Record 34 of Set 6 | lavrentiya
# Processing Record 35 of Set 6 | mahuva
# Processing Record 36 of Set 6 | pochutla
# Processing Record 37 of Set 6 | bela
# Processing Record 38 of Set 6 | paita
# Processing Record 39 of Set 6 | batagay-alyta
# Processing Record 40 of Set 6 | narsaq
# Processing Record 41 of Set 6 | eldikan
# City not found. Skipping...
# Processing Record 42 of Set 6 | geraldton
# Processing Record 43 of Set 6 | cuenca
# Processing Record 44 of Set 6 | copiapo
# Processing Record 45 of Set 6 | kodiak
# Processing Record 46 of Set 6 | long beach
# Processing Record 47 of Set 6 | joshimath
# Processing Record 48 of Set 6 | saint-felicien
# Processing Record 49 of Set 6 | nouadhibou
# Processing Record 50 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 1 of Set 7 | halifax
# Processing Record 2 of Set 7 | honningsvag
# Processing Record 3 of Set 7 | cabo san lucas
# Processing Record 4 of Set 7 | aklavik
# Processing Record 5 of Set 7 | north bend
# Processing Record 6 of Set 7 | rapid valley
# Processing Record 7 of Set 7 | sola
# Processing Record 8 of Set 7 | leningradskiy
# Processing Record 9 of Set 7 | mareeba
# Processing Record 10 of Set 7 | dum duma
# Processing Record 11 of Set 7 | lata
# Processing Record 12 of Set 7 | lensk
# Processing Record 13 of Set 7 | saskylakh
# Processing Record 14 of Set 7 | puerto escondido
# Processing Record 15 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 16 of Set 7 | kupang
# Processing Record 17 of Set 7 | kailua
# Processing Record 18 of Set 7 | luanda
# Processing Record 19 of Set 7 | olinda
# Processing Record 20 of Set 7 | bayanday
# Processing Record 21 of Set 7 | shache
# Processing Record 22 of Set 7 | chanika
# Processing Record 23 of Set 7 | ahuimanu
# Processing Record 24 of Set 7 | pangai
# Processing Record 25 of Set 7 | requena
# Processing Record 26 of Set 7 | virginia beach
# Processing Record 27 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 28 of Set 7 | saint-georges
# Processing Record 29 of Set 7 | gamba
# Processing Record 30 of Set 7 | san carlos de bariloche
# Processing Record 31 of Set 7 | sovetskiy
# Processing Record 32 of Set 7 | lac du bonnet
# Processing Record 33 of Set 7 | wana
# Processing Record 34 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 7 | sao miguel do tapuio
# Processing Record 36 of Set 7 | mount isa
# Processing Record 37 of Set 7 | batagay
# Processing Record 38 of Set 7 | ekibastuz
# Processing Record 39 of Set 7 | hamilton
# Processing Record 40 of Set 7 | luena
# Processing Record 41 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 42 of Set 7 | prieska
# Processing Record 43 of Set 7 | muros
# Processing Record 44 of Set 7 | kuybysheve
# Processing Record 45 of Set 7 | kurilsk
# Processing Record 46 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 7 | imperia
# Processing Record 48 of Set 7 | port hueneme
# Processing Record 49 of Set 7 | kahului
# Processing Record 50 of Set 7 | broken hill
# Processing Record 1 of Set 8 | palafrugell
# Processing Record 2 of Set 8 | kirakira
# Processing Record 3 of Set 8 | korla
# Processing Record 4 of Set 8 | mount gambier
# Processing Record 5 of Set 8 | skjervoy
# Processing Record 6 of Set 8 | ola
# Processing Record 7 of Set 8 | rio gallegos
# Processing Record 8 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 8 | alice springs
# Processing Record 10 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 11 of Set 8 | oranjestad
# Processing Record 12 of Set 8 | basco
# Processing Record 13 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record 14 of Set 8 | phichit
# Processing Record 15 of Set 8 | springfield
# Processing Record 16 of Set 8 | braslav
# City not found. Skipping...
# Processing Record 17 of Set 8 | san juan de colon
# Processing Record 18 of Set 8 | kamina
# Processing Record 19 of Set 8 | ust-tsilma
# Processing Record 20 of Set 8 | ucluelet
# Processing Record 21 of Set 8 | ulaangom
# Processing Record 22 of Set 8 | grand gaube
# Processing Record 23 of Set 8 | evensk
# Processing Record 24 of Set 8 | katsuura
# Processing Record 25 of Set 8 | mujiayingzi
# Processing Record 26 of Set 8 | mahanoro
# Processing Record 27 of Set 8 | alihe
# Processing Record 28 of Set 8 | podgornoye
# Processing Record 29 of Set 8 | vila franca do campo
# Processing Record 30 of Set 8 | iki-burul
# Processing Record 31 of Set 8 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 32 of Set 8 | funadhoo
# Processing Record 33 of Set 8 | kruisfontein
# Processing Record 34 of Set 8 | iquique
# Processing Record 35 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 8 | oshnaviyeh
# Processing Record 37 of Set 8 | zelenogorskiy
# Processing Record 38 of Set 8 | warri
# Processing Record 39 of Set 8 | ulaanbaatar
# Processing Record 40 of Set 8 | graaff-reinet
# Processing Record 41 of Set 8 | darhan
# Processing Record 42 of Set 8 | tuy hoa
# Processing Record 43 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 8 | saint-francois
# Processing Record 45 of Set 8 | pryazha
# Processing Record 46 of Set 8 | ovalle
# Processing Record 47 of Set 8 | surat thani
# Processing Record 48 of Set 8 | rio grande
# Processing Record 49 of Set 8 | vizinga
# Processing Record 50 of Set 8 | turgutlu
# Processing Record 1 of Set 9 | dhidhdhoo
# Processing Record 2 of Set 9 | saldanha
# Processing Record 3 of Set 9 | luderitz
# Processing Record 4 of Set 9 | ancud
# Processing Record 5 of Set 9 | carmen
# Processing Record 6 of Set 9 | pimentel
# Processing Record 7 of Set 9 | kualakapuas
# Processing Record 8 of Set 9 | jacareacanga
# Processing Record 9 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 9 | bambous virieux
# Processing Record 11 of Set 9 | voh
# Processing Record 12 of Set 9 | vidalia
# Processing Record 13 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 14 of Set 9 | melfi
# Processing Record 15 of Set 9 | namibe
# Processing Record 16 of Set 9 | ekhabi
# Processing Record 17 of Set 9 | shelburne
# Processing Record 18 of Set 9 | bellevue
# Processing Record 19 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 9 | yumen
# Processing Record 22 of Set 9 | alashtar
# City not found. Skipping...
# Processing Record 23 of Set 9 | pacific grove
# Processing Record 24 of Set 9 | galle
# Processing Record 25 of Set 9 | hofn
# Processing Record 26 of Set 9 | shaoxing
# Processing Record 27 of Set 9 | porto murtinho
# Processing Record 28 of Set 9 | rafaela
# Processing Record 29 of Set 9 | buta
# Processing Record 30 of Set 9 | gambissara
# Processing Record 31 of Set 9 | potgietersrus
# City not found. Skipping...
# Processing Record 32 of Set 9 | axim
# Processing Record 33 of Set 9 | mwinilunga
# Processing Record 34 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 35 of Set 9 | oum hadjer
# Processing Record 36 of Set 9 | fort-shevchenko
# Processing Record 37 of Set 9 | portland
# Processing Record 38 of Set 9 | zhigansk
# Processing Record 39 of Set 9 | erie
# Processing Record 40 of Set 9 | belaya gora
# Processing Record 41 of Set 9 | ixtapa
# Processing Record 42 of Set 9 | silver city
# Processing Record 43 of Set 9 | dalbandin
# Processing Record 44 of Set 9 | naryan-mar
# Processing Record 45 of Set 9 | tavda
# Processing Record 46 of Set 9 | prince rupert
# Processing Record 47 of Set 9 | natalio
# Processing Record 48 of Set 9 | kitimat
# Processing Record 49 of Set 9 | alyangula
# Processing Record 50 of Set 9 | uchiza
# Processing Record 1 of Set 10 | cervo
# Processing Record 2 of Set 10 | nyurba
# Processing Record 3 of Set 10 | nambucca heads
# Processing Record 4 of Set 10 | tuburan
# Processing Record 5 of Set 10 | astoria
# Processing Record 6 of Set 10 | bridgend
# Processing Record 7 of Set 10 | vetluzhskiy
# Processing Record 8 of Set 10 | gimli
# Processing Record 9 of Set 10 | samarkand
# Processing Record 10 of Set 10 | parintins
# Processing Record 11 of Set 10 | palmer
# Processing Record 12 of Set 10 | bluefields
# Processing Record 13 of Set 10 | shasta lake
# Processing Record 14 of Set 10 | wonthaggi
# Processing Record 15 of Set 10 | tarragona
# Processing Record 16 of Set 10 | berlin
# Processing Record 17 of Set 10 | saint-hyacinthe
# Processing Record 18 of Set 10 | broome
# Processing Record 19 of Set 10 | bossembele
# City not found. Skipping...
# Processing Record 20 of Set 10 | mezen
# Processing Record 21 of Set 10 | kilrush
# Processing Record 22 of Set 10 | faya
# Processing Record 23 of Set 10 | puerto colombia
# Processing Record 24 of Set 10 | rawson
# Processing Record 25 of Set 10 | thinadhoo
# Processing Record 26 of Set 10 | devonport
# Processing Record 27 of Set 10 | yulara
# Processing Record 28 of Set 10 | bull savanna
# Processing Record 29 of Set 10 | igarka
# Processing Record 30 of Set 10 | griffith
# Processing Record 31 of Set 10 | visnes
# Processing Record 32 of Set 10 | ust-nera
# Processing Record 33 of Set 10 | harlow
# Processing Record 34 of Set 10 | sanming
# Processing Record 35 of Set 10 | inyonga
# Processing Record 36 of Set 10 | touros
# Processing Record 37 of Set 10 | heze
# Processing Record 38 of Set 10 | aloleng
# Processing Record 39 of Set 10 | vestmannaeyjar
# Processing Record 40 of Set 10 | anadyr
# Processing Record 41 of Set 10 | henties bay
# Processing Record 42 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 10 | clyde river
# Processing Record 44 of Set 10 | soyo
# Processing Record 45 of Set 10 | osa
# Processing Record 46 of Set 10 | conde
# Processing Record 47 of Set 10 | ahumada
# City not found. Skipping...
# Processing Record 48 of Set 10 | benguela
# Processing Record 49 of Set 10 | aitape
# Processing Record 50 of Set 10 | raga
# Processing Record 1 of Set 11 | ous
# Processing Record 2 of Set 11 | bandarbeyla
# Processing Record 3 of Set 11 | berlevag
# Processing Record 4 of Set 11 | tucurui
# Processing Record 5 of Set 11 | trebukhiv
# Processing Record 6 of Set 11 | caucaia
# Processing Record 7 of Set 11 | kafanchan
# Processing Record 8 of Set 11 | kysyl-syr
# Processing Record 9 of Set 11 | hovsan
# Processing Record 10 of Set 11 | vila velha
# Processing Record 11 of Set 11 | whitehorse
# Processing Record 12 of Set 11 | tezu
# Processing Record 13 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 14 of Set 11 | bathsheba
# Processing Record 15 of Set 11 | college
# Processing Record 16 of Set 11 | padang
# Processing Record 17 of Set 11 | tual
# Processing Record 18 of Set 11 | kargat
# Processing Record 19 of Set 11 | lonar
# Processing Record 20 of Set 11 | chara
# Processing Record 21 of Set 11 | atbasar
# Processing Record 22 of Set 11 | alekseyevsk
# Processing Record 23 of Set 11 | nacozari
# Processing Record 24 of Set 11 | canmore
# Processing Record 25 of Set 11 | terra santa
# Processing Record 26 of Set 11 | dabou
# Processing Record 27 of Set 11 | goksun
# Processing Record 28 of Set 11 | petatlan
# Processing Record 29 of Set 11 | bubaque
# Processing Record 30 of Set 11 | muisne
# Processing Record 31 of Set 11 | shalya
# Processing Record 32 of Set 11 | krasnyy chikoy
# Processing Record 33 of Set 11 | lompoc
# Processing Record 34 of Set 11 | new boston
# Processing Record 35 of Set 11 | lakes entrance
# Processing Record 36 of Set 11 | santa isabel do rio negro
# Processing Record 37 of Set 11 | komsomolskiy
# Processing Record 38 of Set 11 | yatou
# Processing Record 39 of Set 11 | saryg-sep
# Processing Record 40 of Set 11 | wanning
# Processing Record 41 of Set 11 | krutinka
# Processing Record 42 of Set 11 | lithgow
# Processing Record 43 of Set 11 | cockburn town
# Processing Record 44 of Set 11 | krasnoborsk
# Processing Record 45 of Set 11 | baghdad
# Processing Record 46 of Set 11 | cherdyn
# Processing Record 47 of Set 11 | talnakh
# Processing Record 48 of Set 11 | fairbanks
# Processing Record 49 of Set 11 | kulhudhuffushi
# Processing Record 50 of Set 11 | fereydun kenar
# Processing Record 1 of Set 12 | hualmay
# Processing Record 2 of Set 12 | yerbogachen
# Processing Record 3 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 4 of Set 12 | itarema
# Processing Record 5 of Set 12 | kinshasa
# Processing Record 6 of Set 12 | pokhara
# Processing Record 7 of Set 12 | kondinskoye
# Processing Record 8 of Set 12 | srednekolymsk
# Processing Record 9 of Set 12 | flin flon
# Processing Record 10 of Set 12 | buchanan
# Processing Record 11 of Set 12 | sur
# Processing Record 12 of Set 12 | mwanza
# Processing Record 13 of Set 12 | mnogovershinnyy
# Processing Record 14 of Set 12 | mahibadhoo
# Processing Record 15 of Set 12 | cascais
# Processing Record 16 of Set 12 | eichenzell
# Processing Record 17 of Set 12 | sahuaripa
# Processing Record 18 of Set 12 | ouidah
# Processing Record 19 of Set 12 | great bend
# Processing Record 20 of Set 12 | makakilo city
# Processing Record 21 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 12 | nizhniy kuranakh
# Processing Record 23 of Set 12 | magnor
# Processing Record 24 of Set 12 | moose factory
# Processing Record 25 of Set 12 | muroto
# Processing Record 26 of Set 12 | miri
# Processing Record 27 of Set 12 | anito
# Processing Record 28 of Set 12 | isangel
# Processing Record 29 of Set 12 | humboldt
# Processing Record 30 of Set 12 | hami
# Processing Record 31 of Set 12 | mildura
# Processing Record 32 of Set 12 | la rioja
# Processing Record 33 of Set 12 | saryagash
# Processing Record 34 of Set 12 | phangnga
# Processing Record 35 of Set 12 | merauke
# Processing Record 36 of Set 12 | oytal
# Processing Record 37 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 38 of Set 12 | lincoln
# Processing Record 39 of Set 12 | haifa
# Processing Record 40 of Set 12 | laguna
# Processing Record 41 of Set 12 | goure
# Processing Record 42 of Set 12 | kasongo-lunda
# Processing Record 43 of Set 12 | kita
# Processing Record 44 of Set 12 | verdalsora
# City not found. Skipping...
# Processing Record 45 of Set 12 | alexandria
# Processing Record 46 of Set 12 | vostok
# Processing Record 47 of Set 12 | skaerbaek
# Processing Record 48 of Set 12 | ewo
# Processing Record 49 of Set 12 | mtwango
# Processing Record 50 of Set 12 | padilla
# Processing Record 1 of Set 13 | hovd
# Processing Record 2 of Set 13 | karlovac
# Processing Record 3 of Set 13 | belmonte
# Processing Record 4 of Set 13 | zirgan
# Processing Record 5 of Set 13 | agadir
# Processing Record 6 of Set 13 | morondava
# Processing Record 7 of Set 13 | pitelino
# Processing Record 8 of Set 13 | kibiti
# Processing Record 9 of Set 13 | matadi
# Processing Record 10 of Set 13 | shedok
# Processing Record 11 of Set 13 | vanimo
# Processing Record 12 of Set 13 | cap malheureux
# Processing Record 13 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 14 of Set 13 | tashtyp
# Processing Record 15 of Set 13 | tomball
# Processing Record 16 of Set 13 | puerto del rosario
# Processing Record 17 of Set 13 | mulchen
# Processing Record 18 of Set 13 | scarborough
# Processing Record 19 of Set 13 | brokopondo
# Processing Record 20 of Set 13 | battle creek
# Processing Record 21 of Set 13 | goderich
# Processing Record 22 of Set 13 | tondano
# Processing Record 23 of Set 13 | iskateley
# Processing Record 24 of Set 13 | namatanai
# Processing Record 25 of Set 13 | gisborne
# Processing Record 26 of Set 13 | utmanzai
# Processing Record 27 of Set 13 | winnemucca
# Processing Record 28 of Set 13 | yar-sale
# Processing Record 29 of Set 13 | linjiang
# Processing Record 30 of Set 13 | morococha
# Processing Record 31 of Set 13 | darab
# Processing Record 32 of Set 13 | uray
# Processing Record 33 of Set 13 | kyshtovka
# Processing Record 34 of Set 13 | husavik
# Processing Record 35 of Set 13 | iranshahr
# Processing Record 36 of Set 13 | kurush
# Processing Record 37 of Set 13 | taltal
# Processing Record 38 of Set 13 | abu zabad
# Processing Record 39 of Set 13 | lake cowichan
# Processing Record 40 of Set 13 | verkhnevilyuysk
# Processing Record 41 of Set 13 | sarangani
# Processing Record 42 of Set 13 | mathathane
# Processing Record 43 of Set 13 | placido de castro
# Processing Record 44 of Set 13 | marquette
# Processing Record 45 of Set 13 | acarau
# Processing Record 46 of Set 13 | constitucion
# Processing Record 47 of Set 13 | okha
# Processing Record 48 of Set 13 | breyten
# Processing Record 49 of Set 13 | paamiut
# Processing Record 50 of Set 13 | anloga
# Processing Record 1 of Set 14 | abha
# Processing Record 2 of Set 14 | yarkovo
# Processing Record 3 of Set 14 | fonte boa
# Processing Record 4 of Set 14 | asfi
# Processing Record 5 of Set 14 | ketchikan
# Processing Record 6 of Set 14 | madimba
# Processing Record 7 of Set 14 | riyadh
# Processing Record 8 of Set 14 | aksu
# Processing Record 9 of Set 14 | smithers
# Processing Record 10 of Set 14 | old town
# Processing Record 11 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 12 of Set 14 | roald
# Processing Record 13 of Set 14 | kuala terengganu
# Processing Record 14 of Set 14 | beira
# Processing Record 15 of Set 14 | sosnovo-ozerskoye
# Processing Record 16 of Set 14 | tutayev
# Processing Record 17 of Set 14 | hukuntsi
# Processing Record 18 of Set 14 | orlik
# Processing Record 19 of Set 14 | bandarban
# Processing Record 20 of Set 14 | romodanovo
# Processing Record 21 of Set 14 | siuna
# Processing Record 22 of Set 14 | verkhnyaya sysert
# Processing Record 23 of Set 14 | talara
# Processing Record 24 of Set 14 | camabatela
# Processing Record 25 of Set 14 | kuah
# Processing Record 26 of Set 14 | bac lieu
# Processing Record 27 of Set 14 | teya
# Processing Record 28 of Set 14 | tigre
# Processing Record 29 of Set 14 | ha tinh
# Processing Record 30 of Set 14 | onguday
# Processing Record 31 of Set 14 | sambhal
# Processing Record 32 of Set 14 | sao jose da coroa grande
# Processing Record 33 of Set 14 | walvis bay
# Processing Record 34 of Set 14 | quatre cocos
# Processing Record 35 of Set 14 | shimoda
# Processing Record 36 of Set 14 | kurchum
# Processing Record 37 of Set 14 | varna
# Processing Record 38 of Set 14 | almaznyy
# Processing Record 39 of Set 14 | gushikawa
# Processing Record 40 of Set 14 | katherine
# Processing Record 41 of Set 14 | bitung
# Processing Record 42 of Set 14 | pauini
# Processing Record 43 of Set 14 | santa rosa
# Processing Record 44 of Set 14 | teknaf
# Processing Record 45 of Set 14 | popondetta
# Processing Record 46 of Set 14 | ovsyanka
# Processing Record 47 of Set 14 | ipameri
# Processing Record 48 of Set 14 | pokosnoye
# Processing Record 49 of Set 14 | kapustin yar
# Processing Record 50 of Set 14 | kibaya
# Processing Record 1 of Set 15 | vardo
# Processing Record 2 of Set 15 | tivaouane
# Processing Record 3 of Set 15 | pillaro
# Processing Record 4 of Set 15 | haverfordwest
# Processing Record 5 of Set 15 | ascension
# Processing Record 6 of Set 15 | coos bay
# Processing Record 7 of Set 15 | yangshe
# Processing Record 8 of Set 15 | wilmington
# Processing Record 9 of Set 15 | salinopolis
# Processing Record 10 of Set 15 | cuiluan
# Processing Record 11 of Set 15 | burshtyn
# Processing Record 12 of Set 15 | richards bay
# Processing Record 13 of Set 15 | tooele
# Processing Record 14 of Set 15 | port augusta
# Processing Record 15 of Set 15 | saint-pierre
# Processing Record 16 of Set 15 | half moon bay
# Processing Record 17 of Set 15 | del rio
# Processing Record 18 of Set 15 | harnosand
# Processing Record 19 of Set 15 | maltahohe
# Processing Record 20 of Set 15 | milingimbi
# City not found. Skipping...
# Processing Record 21 of Set 15 | tucupita
# Processing Record 22 of Set 15 | liwale
# Processing Record 23 of Set 15 | benjamin hill
# Processing Record 24 of Set 15 | bimbo
# Processing Record 25 of Set 15 | mogochin
# City not found. Skipping...
# Processing Record 26 of Set 15 | yumaguzino
# Processing Record 27 of Set 15 | coxim
# Processing Record 28 of Set 15 | araguatins
# City not found. Skipping...
# Processing Record 29 of Set 15 | zhaotong
# Processing Record 30 of Set 15 | miracema do tocantins
# Processing Record 31 of Set 15 | rodrigues alves
# Processing Record 32 of Set 15 | deputatskiy
# Processing Record 33 of Set 15 | tando adam
# Processing Record 34 of Set 15 | fort nelson
# Processing Record 35 of Set 15 | osoyoos
# Processing Record 36 of Set 15 | mocuba
# Processing Record 37 of Set 15 | khilok
# Processing Record 38 of Set 15 | tianpeng
# Processing Record 39 of Set 15 | aden
# Processing Record 40 of Set 15 | trairi
# Processing Record 41 of Set 15 | kadyy
# Processing Record 42 of Set 15 | linqiong
# Processing Record 43 of Set 15 | zeya
# Processing Record 44 of Set 15 | tandil
# Processing Record 45 of Set 15 | lakatoro
# Processing Record 46 of Set 15 | flinders
# Processing Record 47 of Set 15 | ljig
# Processing Record 48 of Set 15 | imeni poliny osipenko
# Processing Record 49 of Set 15 | dindori
# Processing Record 50 of Set 15 | trojan
# Processing Record 1 of Set 16 | wasilla
# Processing Record 2 of Set 16 | camacha
# Processing Record 3 of Set 16 | bettiah
# Processing Record 4 of Set 16 | mogadishu
# Processing Record 5 of Set 16 | phan rang
# City not found. Skipping...
# Processing Record 6 of Set 16 | bogorodskoye
# Processing Record 7 of Set 16 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 16 | whitecourt
# Processing Record 9 of Set 16 | ossora
# Processing Record 10 of Set 16 | tecoanapa
# Processing Record 11 of Set 16 | khalkhal
# Processing Record 12 of Set 16 | ostersund
# Processing Record 13 of Set 16 | prado
# Processing Record 14 of Set 16 | nyrob
# Processing Record 15 of Set 16 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 16 | kajaani
# Processing Record 17 of Set 16 | kidal
# Processing Record 18 of Set 16 | erdenet
# Processing Record 19 of Set 16 | verdun
# Processing Record 20 of Set 16 | matara
# Processing Record 21 of Set 16 | el vigia
# Processing Record 22 of Set 16 | boca do acre
# Processing Record 23 of Set 16 | qui nhon
# Processing Record 24 of Set 16 | marsa matruh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo      BR -22.9661  -42.0278     85.86        58           0
# 1          Rikitea      PF -23.1203 -134.9692     77.18        77          84
# 2        Busselton      AU -33.6500  115.3333     57.22        73          33
# 3             Bend      US  44.0582 -121.3153     41.99        70           0
# 4      East London      ZA -33.0153   27.9116     76.14        60           0
# 5          Ahipara      NZ -35.1667  173.1667     56.01        86          65
# 6          Ushuaia      AR -54.8000  -68.3000     42.42        75          75
# 7        Montlucon      FR  46.3333    2.6000     67.69        55          24
# 8          Aquiraz      BR  -3.9014  -38.3911     89.69        80          80
# 9           Hobart      AU -42.8794  147.3294     62.46        66          75
#
#    Wind Speed Current Description
# 0       13.80           clear sky
# 1       16.06       broken clouds
# 2       10.40    scattered clouds
# 3        5.01           clear sky
# 4        4.61           clear sky
# 5        6.02       broken clouds
# 6        4.61       broken clouds
# 7        7.96          few clouds
# 8       13.27       broken clouds
# 9       14.97       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label = "City_ID")
